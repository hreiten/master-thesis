# %%
! which python
# Out:
# /home/shomeb/t/thomklei/master_thesis/venv/bin/python

# %%
import pandas as pd

# %%
! which python
# Out:
# /home/shomeb/t/thomklei/master_thesis/venv/bin/python

# %%
pd.read_pickle('df_scaled_test.pkl')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/pandas/io/pickle.py in try_read(path, encoding)
#     165                 # We want to silencce any warnings about, e.g. moved modules.
# --> 166                 return read_wrapper(lambda f: pkl.load(f))
#     167         except Exception:
#
# ~/.local/lib/python3.6/site-packages/pandas/io/pickle.py in read_wrapper(func)
#     148         try:
# --> 149             return func(f)
#     150         finally:
#
# ~/.local/lib/python3.6/site-packages/pandas/io/pickle.py in <lambda>(f)
#     165                 # We want to silencce any warnings about, e.g. moved modules.
# --> 166                 return read_wrapper(lambda f: pkl.load(f))
#     167         except Exception:
#
# ModuleNotFoundError: No module named 'numpy.core._multiarray_umath'
#
# ...
